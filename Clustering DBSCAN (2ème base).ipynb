# %%
import numpy as np
import matplotlib.pyplot as plt
import os.path
from sklearn.metrics import silhouette_score, calinski_harabasz_score
from DBSCAN_Clustering import dbscan_clustering_sklearn

# %%
X = np.load(os.path.join(os.path.abspath("résultats (2ème base)"),"Features_matrix_2(scaled).npy"))
print(X.shape)
N = X.shape[0]
# Out:
# (600, 297)

# %%
# minPts_array = np.arange(4,5,1)
n_eps = 5
silhouette_score_array = np.zeros(n_eps)
calinski_harabasz_score_array = np.zeros(n_eps)

# %% [markdown]
# ## Distance euclidienne

# %%
metric_ = "euclidean"
minPts = 4
eps_min = 7.8
eps_max = 8.3
eps_array = np.arange(eps_min, eps_max, (eps_max-eps_min)/n_eps)

for i in range(n_eps):
    classes = dbscan_clustering_sklearn(X,eps_array[i],minPts,metric_)
    n_clusters = np.max(classes)+1
    print(n_clusters)
    silhouette_score_array[i] = silhouette_score(X,classes)
    calinski_harabasz_score_array[i] = calinski_harabasz_score(X,classes)*(n_clusters-1)/(N-n_clusters)
# Out:
# 2
# 3
# 4
# 4
# 3

# %%
np.save(os.path.join(os.path.abspath("résultats (2ème base)"),"Silhouette_score_dbscan(euclidean)"), silhouette_score_array)

# %%
np.save(os.path.join(os.path.abspath("résultats (2ème base)"),"Calinski_harabasz_dbscan(euclidean)"), calinski_harabasz_score_array)

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(1,2,1)
ax1.plot(eps_array, silhouette_score_array)
ax1.set_title("Silhouette_score")
ax1.set_xlabel("eps")
ax2 = plt.subplot(1,2,2)
ax2.plot(eps_array, calinski_harabasz_score_array)
ax2.set_title("Calinski_harabasz_score ")
ax2.set_xlabel("eps")
plt.show()

# %% [markdown]
# ## Distance Manhattan

# %%
metric_ = "manhattan"
minPts = 4
eps_min = 114
eps_max = 116
eps_array = np.linspace(eps_min, eps_max, n_eps)

for i in range(n_eps):
    classes = dbscan_clustering_sklearn(X,eps_array[i],minPts,metric_)
    n_clusters = np.max(classes)+1
    print(n_clusters)
    silhouette_score_array[i] = silhouette_score(X,classes)
    calinski_harabasz_score_array[i] = calinski_harabasz_score(X,classes)*(n_clusters-1)/(N-n_clusters)
# Out:
# 2
# 3
# 3
# 1
# 1

# %%
np.save(os.path.join(os.path.abspath("résultats (2ème base)"),"Silhouette_score_dbscan(manhattan)"), silhouette_score_array)

# %%
np.save(os.path.join(os.path.abspath("résultats (2ème base)"),"Calinski_harabasz_dbscan(manhattan)"), calinski_harabasz_score_array)

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(1,2,1)
ax1.plot(eps_array, silhouette_score_array)
ax1.set_title("Silhouette_score")
ax1.set_xlabel("eps")
ax2 = plt.subplot(1,2,2)
ax2.plot(eps_array, calinski_harabasz_score_array)
ax2.set_title("Calinski_harabasz_score ")
ax2.set_xlabel("eps")
plt.show()

# %% [markdown]
# ## Distance Cosine

# %%
metric_ = "cosine"
minPts = 4 
eps_min = 0.3
eps_max = 0.5
eps_array = np.linspace(eps_min, eps_max, n_eps)

for i in range(n_eps):
    classes = dbscan_clustering_sklearn(X,eps_array[i],minPts,metric_)
    n_clusters = np.max(classes)+1
    print(n_clusters)
    silhouette_score_array[i] = silhouette_score(X,classes)
    calinski_harabasz_score_array[i] = calinski_harabasz_score(X,classes)*(n_clusters-1)/(N-n_clusters)
# Out:
# 3
# 2
# 5
# 5
# 6

# %%
np.save(os.path.join(os.path.abspath("résultats (2ème base)"),"Silhouette_score_dbscan(cosine)"), silhouette_score_array)

# %%
np.save(os.path.join(os.path.abspath("résultats (2ème base)"),"Calinski_harabasz_dbscan(cosine)"), calinski_harabasz_score_array)

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(1,2,1)
ax1.plot(eps_array, silhouette_score_array)
ax1.set_title("Silhouette_score")
ax1.set_xlabel("eps")
ax2 = plt.subplot(1,2,2)
ax2.plot(eps_array, calinski_harabasz_score_array)
ax2.set_title("Calinski_harabasz_score ")
ax2.set_xlabel("eps")
plt.show()

# %% [markdown]
# ## Distance Chebyshev

# %%
metric_ = "chebyshev"
minPts = 4
eps_min = 1.95
eps_max = 2.15
eps_array = np.linspace(eps_min, eps_max, n_eps)

for i in range(n_eps):
    classes = dbscan_clustering_sklearn(X,eps_array[i],minPts,metric_)
    n_clusters = np.max(classes)+1
    print(n_clusters)
    silhouette_score_array[i] = silhouette_score(X,classes)
    calinski_harabasz_score_array[i] = calinski_harabasz_score(X,classes)*(n_clusters-1)/(N-n_clusters)
# Out:
# 1
# 3
# 2
# 2
# 1

# %%
np.save(os.path.join(os.path.abspath("résultats (2ème base)"),"Silhouette_score_dbscan(chebyshev)"), silhouette_score_array)

# %%
np.save(os.path.join(os.path.abspath("résultats (2ème base)"),"Calinski_harabasz_dbscan(chebyshev)"), calinski_harabasz_score_array)

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(1,2,1)
ax1.plot(eps_array, silhouette_score_array)
ax1.set_title("Silhouette_score")
ax1.set_xlabel("eps")
ax2 = plt.subplot(1,2,2)
ax2.plot(eps_array, calinski_harabasz_score_array)
ax2.set_title("Calinski_harabasz_score ")
ax2.set_xlabel("eps")
plt.show()

# %%
calinski_harabasz_euclidean = np.load(os.path.join(os.path.abspath("résultats (2ème base)"),"Calinski_harabasz_dbscan(euclidean).npy"))
calinski_harabasz_manhattan = np.load(os.path.join(os.path.abspath("résultats (2ème base)"),"Calinski_harabasz_dbscan(manhattan).npy"))
calinski_harabasz_cosine = np.load(os.path.join(os.path.abspath("résultats (2ème base)"),"Calinski_harabasz_dbscan(cosine).npy"))
calinski_harabasz_chebyshev = np.load(os.path.join(os.path.abspath("résultats (2ème base)"),"Calinski_harabasz_dbscan(chebyshev).npy"))

distances = ["euclidean", "manhattan", "cosine", "chebyshev"]
calinski_harabasz = [np.max(calinski_harabasz_euclidean), np.max(calinski_harabasz_manhattan), np.max(calinski_harabasz_cosine), np.max(calinski_harabasz_chebyshev)]
plt.figure()
plt.barh(distances, calinski_harabasz)
plt.title("calinski_harabasz_index vs distances (DBSCAN Clustering)")
plt.show()
